# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
from ultralytics import YOLO
import torch

# Load a model
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# Check if CUDA is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Train the model with the specified device
results = model.train(data='data.yaml', epochs=20, imgsz=640, device=device)
# Out:
# Using device: cuda
# ...

# %%
# Validate model

from ultralytics import YOLO

# Load a model
model = YOLO('runs/detect/train/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.2.74  Python-3.11.8 torch-2.4.0+cu124 CUDA:0 (NVIDIA RTX A6000, 49140MiB)
# Model summary (fused): 168 layers, 3,007,988 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\meenakshi.malviya\Downloads\Visual-cooking-assistant.v2i.yolov8\valid\labels.cache... 188 images, 12 backgrounds, 0 corrupt: 100%|██████████| 188/188 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 12/12 [00:01<00:00, 11.61it/s]
#                    all        188        740      0.825      0.712       0.76      0.616
#                Chicken          2          2          1          0          0          0
#                 Tomato         19        111      0.951      0.874      0.953       0.78
#                  bread         25         78      0.788      0.573      0.749      0.535
#                cabbage         13         32       0.86      0.765      0.877      0.771
# ...

# %%
#  Prediction using trained model

from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('runs/detect/train/weights/best.pt')

# Run inference 
model.predict('test/images', save=True, imgsz=640, conf=0.2)
# Out:
# image 1/95 c:\Users\meenakshi.malviya\Downloads\Visual-cooking-assistant.v2i.yolov8\test\images\Cabbage12_jpg.rf.7d0d22189ae2c313c66d467bce8b3108.jpg: 640x640 12 cabbages, 0.0ms
# image 2/95 c:\Users\meenakshi.malviya\Downloads\Visual-cooking-assistant.v2i.yolov8\test\images\Cabbage16_jpg.rf.0a8706a18d0618d44f67b1f521b7f8ea.jpg: 640x640 1 cabbage, 0.0ms
# image 3/95 c:\Users\meenakshi.malviya\Downloads\Visual-cooking-assistant.v2i.yolov8\test\images\Cabbage44_JPG.rf.b7b9a7582c72055b22c98546bc3dff1b.jpg: 640x640 2 cabbages, 4.0ms
# image 4/95 c:\Users\meenakshi.malviya\Downloads\Visual-cooking-assistant.v2i.yolov8\test\images\Cabbage58_jpg.rf.67c3911a9ed266efdb0058147d49e814.jpg: 640x640 1 cabbage, 3.0ms
# image 5/95 c:\Users\meenakshi.malviya\Downloads\Visual-cooking-assistant.v2i.yolov8\test\images\Cabbage68_jpg.rf.efb795a8faf4aa583d95a3f63019ffa8.jpg: 640x640 1 cabbage, 2.7ms
# ...

# %%
#  Export model to tflite


from ultralytics import YOLO

# Load a model
model = YOLO('runs/detect/train/weights/best.pt')  # load a custom trained model

# Export the model
model.export(format='tflite')
# Out:
# Ultralytics YOLOv8.2.74  Python-3.11.8 torch-2.4.0+cu124 CPU (Intel Core(TM) i9-14900K)
# Model summary (fused): 168 layers, 3,007,988 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from 'runs\detect\train\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 16, 8400) (6.0 MB)
# requirements: Ultralytics requirement ['tensorflow>=2.0.0'] not found, attempting AutoUpdate...
# ...
#      -------------------------------------- 48.7/48.7 kB 818.0 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 385.0/385.0 MB 6.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 133.7/133.7 kB 7.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 57.5/57.5 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 4.1/4.1 MB 8.0 MB/s eta 0:00:001
# ...
#    ---------------------------------------- 3.0/3.0 MB 9.1 MB/s eta 0:00:001
# ...
#    ---------------------------------------- 1.1/1.1 MB 11.9 MB/s eta 0:00:00
# ...
